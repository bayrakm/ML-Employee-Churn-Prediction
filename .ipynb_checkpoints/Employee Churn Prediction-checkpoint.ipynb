# %% [markdown]
# # Determines
# In this project I have HR data of a company. A study is requested from me to predict which employee will churn by using this data.
#
# The HR dataset has 14,999 samples. In the given dataset, you have two types of employee one who stayed and another who left the company.
#
# You can describe 10 attributes in detail as:
# - ***satisfaction_level:*** It is employee satisfaction point, which ranges from 0-1.
# - ***last_evaluation:*** It is evaluated performance by the employer, which also ranges from 0-1.
# - ***number_projects:*** How many of projects assigned to an employee?
# - ***average_monthly_hours:*** How many hours in averega an employee worked in a month?
# - **time_spent_company:** time_spent_company means employee experience. The number of years spent by an employee in the company.
# - ***work_accident:*** Whether an employee has had a work accident or not.
# - ***promotion_last_5years:*** Whether an employee has had a promotion in the last 5 years or not.
# - ***Departments:*** Employee's working department/division.
# - ***Salary:*** Salary level of the employee such as low, medium and high.
# - ***left:*** Whether the employee has left the company or not.
#
# First of all, to observe the structure of the data, outliers, missing values and features that affect the target variable, I must use exploratory data analysis and data visualization techniques.
#
# Then, I will perform data pre-processing operations such as ***Scaling*** and ***Label Encoding*** to increase the accuracy score of Gradient Descent Based or Distance-Based algorithms. I am asked to perform ***Cluster Analysis*** based on the information I obtain during exploratory data analysis and data visualization processes.
#
# The purpose of clustering analysis is to cluster data with similar characteristics. I am asked to use the ***K-means*** algorithm to make cluster analysis. However, I must provide the K-means algorithm with information about the number of clusters it will make predictions. Also, the data I apply to the K-means algorithm must be scaled. In order to find the optimal number of clusters, I will use the ***Elbow method***. Briefly, try to predict the set to which individuals are related by using K-means and evaluate the estimation results.
#
# Once the data is ready to be applied to the model, I need to ***split the data into train and test***. Then build a model to predict whether employees will churn or not. Train my models with the train set, test the success of your model with the test set.
#
# I am going to try to make predictions by using the algorithms ***Gradient Boosting Classifier***, ***K Neighbors Classifier***, ***Random Forest Classifier***. I will use the related modules of the ***scikit-learn*** library. I will use scikit-learn ***Confusion Metrics*** module for accuracy calculation. I will use the ***Yellowbrick*** module for model selection and visualization.
#
# In the final step, I am going to deploy the model using Streamlit tool.

# %% [markdown]
# # Tasks
#
# #### <a href="#1.-Exploratory-Data-Analysis">1.Exploratory Data Analysis</a>
# - Importing Modules
# - Loading Dataset
# - Data Insigts
#
# #### <a href="#2.-Data-Visualization">2.Data Visualization</a>
# - Employees Left
# - Determine Number of Projects
# - Determine Time Spent in Company
# - Subplots of Features
#
# #### <a href="#3.-Data-Pre-Processing">3.Data Pre-Processing</a>
# - Scaling
# - Label Encoding
#
# #### <a href="#4.-Cluster-Analysis">4.Cluster Analysis</a>
# - Find the optimal number of clusters (k) using the elbow method for for K-means.
# - Determine the clusters by using K-Means then Evaluate predicted results.
#
# #### <a href="#5.-Model-Building">5.Model Building</a>
# - Split Data as Train and Test set
# - Built Gradient Boosting Classifier, Evaluate Model Performance and Predict Test Data
# - Built K Neighbors Classifier and Evaluate Model Performance and Predict Test Data
# - Built Random Forest Classifier and Evaluate Model Performance and Predict Test Data
#
# #### <a href="#6.-Model-Deployement">6.Model Deployement</a>
#
# - Save and Export the Model as .pkl
# - Save and Export Variables as .pkl

# %% [markdown]
# ## 1. Exploratory Data Analysis
#
# Exploratory Data Analysis is an initial process of analysis, in which you can summarize characteristics of data such as pattern, trends, outliers, and hypothesis testing using descriptive statistics and visualization.

# %%
# to check the description of a feature

def explain(feature):
    features = {'satisfaction_level': 'It is employee satisfaction point, which ranges from 0-1.',
'last_evaluation' : 'It is evaluated performance by the employer, which also ranges from 0-1.',
'number_projects' : 'How many of projects assigned to an employee?',
'average_monthly_hours': 'How many hours in averega an employee worked in a month?',
'time_spent_company' : 'time_spent_company means employee experience. The number of years spent by an employee in the company.',
'work_accident' : 'Whether an employee has had a work accident or not.',
'promotion_last_5years' : 'Whether an employee has had a promotion in the last 5 years or not.',
'Departments' : "Employee's working department/division.",
'Salary' : 'Salary level of the employee such as low, medium and high.',
'left' : 'Whether the employee has left the company or not.'}
    return features[feature]

# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from yellowbrick.cluster import KElbowVisualizer

# %% [markdown]
# ### Loading Dataset
#
# Let's first load the required HR dataset using pandas's "read_csv" function.

# %%
df = pd.read_csv('HR_Dataset.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Departments            14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments ', 'salary'],
#       dtype='object')

# %%
df.rename(columns={'Departments ' : 'departments'}, inplace=True)

# %%
df['departments'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: departments, dtype: int64

# %% [markdown]
# ### Data Insights
#
# In the given dataset, you have two types of employee one who stayed and another who left the company. So, you can divide data into two groups and compare their characteristics. Here, you can find the average of both the groups using groupby() and mean() function.

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# **Things to check**
# * left employees avg. number of project is higher.
# * left employees monthly hour rate is higher.
# * left employees spend more time in the company.
# * left employees has 4 times less work accident. <br>
# At a glance, it looks the left employees works harder in terms of hours or projects and they are good in their work in accordance to work accident report however they are not promoted.

# %% [markdown]
# <a href="#1.-Exploratory-Data-Analysis">Back to top</a>

# %% [markdown]
# ## 2. Data Visualization
#
# I am going to search for answers to the following questions using data visualization methods. Based on these responses, I would develop comments about the factors that cause churn.
# - How does the promotion status affect employee churn?
# - How does years of experience affect employee churn?
# - How does workload affect employee churn?
# - How does the salary level affect employee churn?

# %% [markdown]
# ### Employees Left
#
# Let's check how many employees were left?
# Here, you can plot a bar graph using Matplotlib. The bar graph is suitable for showing discrete variable counts.

# %%
df.groupby('left')['left'].count()/14999
# Out:
# left
# 0    0.761917
# 1    0.238083
# Name: left, dtype: float64

# %%
color = ['maroon', 'mediumaquamarine', 'gray', 'darkorange', 'blue', 'pink', 'goldenrod', 'midnightblue', 'salmon', 'limegreen']

df.groupby('left')['left'].count().plot.bar(figsize=(8, 8), color=color)
# Out:
# <AxesSubplot:xlabel='left'>

# %% [markdown]
# **Insights**
# * Near a forth of the employees are left the company over the time.

# %%
plt.figure(figsize=(15,12))

plt.subplot(2,2,1)
(df[df['left']==1].groupby('departments')['left'].value_counts()/df.groupby('departments')['departments'].value_counts()*100).plot.bar( color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('% of left employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.xticks([])

plt.subplot(2,2,2)
df[df['left']==1].groupby('departments')['left'].value_counts().plot.bar( color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('Number of left employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.xticks([])

plt.subplot(2,2,3)
(df[df['left']==0].groupby('departments')['left'].value_counts()/df.groupby('departments')['departments'].value_counts()*100).plot.bar( color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('% of current employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Departments', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xticks([])

plt.subplot(2,2,4)
df[df['left']==0].groupby('departments')['left'].value_counts().plot.bar( color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('Number of current employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Departments', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.tight_layout()

# %% [markdown]
# **Insights**
# * The highest % of the left employee -- HR --> Accounting --> Technical
# * The least % of the left employee -- Management --> RandD --> Product_mng
# * The highest number of left employee -- Sales --> Technical --> Support
# * The least number of left employee -- Management --> RandD --> Product_mng

# %%
plt.figure(figsize=(10,12))

plt.subplot(2,1,1)
(df[df['left']==1].groupby('salary')['left'].value_counts()/df.groupby('salary')['salary'].value_counts() *100).plot.bar( color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('% of left employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,1,2)
(df[df['left']==0].groupby('salary')['left'].value_counts()/df.groupby('salary')['salary'].value_counts()*100).plot.bar( color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('% of current employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Salary Level', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.tight_layout()

# %% [markdown]
# **Insights**
# * %30 of low paid employee is the highest number in terms of salary.

# %% [markdown]
# ### Number of Projects
#
# Similarly, you can also plot a bar graph to count the number of employees deployed on how many projects?

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,2,1)
(df[df['left']==1].groupby('number_project')['left'].value_counts()/df.groupby('number_project')['number_project'].value_counts() *100).plot.bar( color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('% of left employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,2,2)
df[df['left']==1].groupby('number_project')['left'].value_counts().plot.bar( color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('Number of left employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,2,3)
(df[df['left']==0].groupby('number_project')['left'].value_counts()/df.groupby('number_project')['number_project'].value_counts() *100).plot.bar( color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('% of current employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Number of Projects', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.subplot(2,2,4)
df[df['left']==0].groupby('number_project')['left'].value_counts().plot.bar( color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('Number of current employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Number of Projects', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.tight_layout()

# %% [markdown]
# **Insights**
# * All employees left who worked on 7 projects.
# * Number of left employee gradually increase by increasing number of project that they worked on.
# * Top number of left employee is who worked on 2 projects.

# %% [markdown]
# ### Time Spent in Company
#
# Similarly, you can also plot a bar graph to count the number of employees have based on how much experience?

# %%
s = df[df['left']==1].groupby('time_spend_company')['left'].value_counts()

plt.figure(figsize=(20,10))

plt.subplot(2,2,1)
(s/14999 *100).plot.bar(color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('Number of left employee %', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,2,2)
s.plot.bar(color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('Number of left employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,2,3)
(df[df['left']==0].groupby('time_spend_company')['left'].value_counts()/14999 *100).plot.bar(color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('Number of current employee %', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Time in Company (years)', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.subplot(2,2,4)
df[df['left']==0].groupby('time_spend_company')['left'].value_counts().plot.bar(color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('Number of current employee', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Time in Company (years)', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.tight_layout()

# %% [markdown]
# **Insights**
# * None of the employee left who worked over six years in the company.
# * Most of the employee leave the company in the third year.
# * Least number and percentage of employee who leave the company is in the firts year.

# %% [markdown]
# ### Subplots of Features
#
# You can use the methods of the matplotlib.

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years departments  \
# 0                   3              0     1                      0       sales
# 1                   6              0     1                      0       sales
# 2                   4              0     1                      0       sales
# 3                   5              0     1                      0       sales
# 4                   3              0     1                      0       sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
plt.figure(figsize=(20,10))

plt.subplot(2,3,1)
(df[df['left']==1].groupby('Work_accident')['left'].value_counts()/df.groupby('Work_accident')['Work_accident'].value_counts()*100).plot.bar(color=color)
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('% Work Accidents', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,3,4)
(df[df['left']==0].groupby('Work_accident')['left'].value_counts()/df.groupby('Work_accident')['Work_accident'].value_counts()*100).plot.bar(color=color)
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('% Work Accidents', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Work Accidents', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})

plt.subplot(2,3,2)
(df[df['left']==1].groupby('promotion_last_5years')['left'].value_counts()/df.groupby('promotion_last_5years')['promotion_last_5years'].value_counts()*100).plot.bar(color=color[2:4])
plt.title('Left Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'lightseagreen'})
plt.ylabel('% promotions in 5 years', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'lightseagreen'})

plt.subplot(2,3,5)
(df[df['left']==0].groupby('promotion_last_5years')['left'].value_counts()/df.groupby('promotion_last_5years')['promotion_last_5years'].value_counts()*100).plot.bar(color=color[2:4])
plt.title('Current Employees', fontdict= {'fontsize': 20,'fontweight': 'bold', 'color' : 'coral'})
plt.ylabel('% promotions in 5 years', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})
plt.xlabel('Promotions in 5 years', fontdict= {'fontsize': 15,'fontweight': 'bold', 'color' : 'coral'})



plt.tight_layout()

# %% [markdown]
# **Insight**
# * Left employees has less work accident rate.
# * Left employees promotion rate is around 5%.

# %% [markdown]
# ## 3. Data Pre-Processing

# %% [markdown]
# <a href="#1.-Exploratory-Data-Analysis">Back to top</a>

# %% [markdown]
# #### Scaling
#
# Some machine learning algorithms are sensitive to feature scaling while others are virtually invariant to it. Machine learning algorithms like linear regression, logistic regression, neural network, etc. that use gradient descent as an optimization technique require data to be scaled. Also distance algorithms like KNN, K-means, and SVM are most affected by the range of features. This is because behind the scenes they are using distances between data points to determine their similarity.
#
# Scaling Types:
# - Normalization: Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.
#
# - Standardization: Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation.

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years departments  \
# 0                   3              0     1                      0       sales
# 1                   6              0     1                      0       sales
# 2                   4              0     1                      0       sales
# 3                   5              0     1                      0       sales
# 4                   3              0     1                      0       sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# #### Label Encoding
#
# Lots of machine learning algorithms require numerical input data, so you need to represent categorical columns in a numerical column. In order to encode this data, you could map each value to a number. e.g. Salary column's value can be represented as low:0, medium:1, and high:2. This process is known as label encoding, and sklearn conveniently will do this for you using LabelEncoder.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
df['departments'] = labelencoder.fit_transform(df['departments'])
df['salary'] = labelencoder.fit_transform(df['salary'])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#    departments  salary
# 0            7       1
# 1            7       2
# 2            7       2
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'departments', 'salary'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmaxscaler = MinMaxScaler() #feature_range attribute specifies the scaling range.
df_sc_minmax = minmaxscaler.fit_transform(df.drop(['departments', 'left'], axis=1))

# %%
df_sc_minmax = pd.DataFrame(df_sc_minmax, columns=['satisfaction_level', 'last_evaluation', 'number_project',
       'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 'salary'])

# %%
df_sc_minmax.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0            0.318681         0.265625             0.0              0.285047
# 1            0.780220         0.781250             0.6              0.775701
# 2            0.021978         0.812500             1.0              0.822430
# 3            0.692308         0.796875             0.6              0.593458
# 4            0.307692         0.250000             0.0              0.294393
#
#    time_spend_company  Work_accident  promotion_last_5years
# 0               0.125            0.0                    0.0
# 1               0.500            0.0                    0.0
# 2               0.250            0.0                    0.0
# 3               0.375            0.0                    0.0
# 4               0.125            0.0                    0.0

# %%
df_sc_minmax['left'] = df['left']

# %%
from sklearn.preprocessing import StandardScaler

# %%
stscaler = StandardScaler()
df_sc_std = stscaler.fit_transform(df.drop(['departments', 'left'], axis=1))
df_sc_std = pd.DataFrame(df_sc_std, columns=['satisfaction_level', 'last_evaluation', 'number_project',
       'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 'salary'])

# %%
df_sc_std.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0           -0.936495        -1.087275       -1.462863             -0.882040
# 1            0.752814         0.840707        0.971113              1.220423
# 2           -2.022479         0.957554        2.593763              1.420657
# 3            0.431041         0.899131        0.971113              0.439508
# 4           -0.976716        -1.145699       -1.462863             -0.841993
#
#    time_spend_company  Work_accident  promotion_last_5years    salary
# 0           -0.341235      -0.411165              -0.147412 -0.554955
# 1            1.713436      -0.411165              -0.147412  1.043004
# 2            0.343655      -0.411165              -0.147412  1.043004
# 3            1.028546      -0.411165              -0.147412 -0.554955
# 4           -0.341235      -0.411165              -0.147412 -0.554955

# %%
df_sc_std['left'] = df['left']

# %% [markdown]
# <a href="#1.-Exploratory-Data-Analysis">Back to top</a>

# %% [markdown]
# ## 4. Cluster Analysis
#
# - Cluster analysis or clustering is the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters). It is a main task of exploratory data mining, and a common technique for statistical data analysis, used in many fields, including pattern recognition, image analysis, information retrieval, bioinformatics, data compression, computer graphics and machine learning.
#
#     [Cluster Analysis](https://en.wikipedia.org/wiki/Cluster_analysis)
#
#     [Cluster Analysis2](https://realpython.com/k-means-clustering-python/)

# %% [markdown]
# #### The Elbow Method
#
# - "Elbow Method" can be used to find the optimum number of clusters in cluster analysis. The elbow method is used to determine the optimal number of clusters in k-means clustering. The elbow method plots the value of the cost function produced by different values of k. If k increases, average distortion will decrease, each cluster will have fewer constituent instances, and the instances will be closer to their respective centroids. However, the improvements in average distortion will decline as k increases. The value of k at which improvement in distortion declines the most is called the elbow, at which we should stop dividing the data into further clusters.
#
#     [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)
#
#     [The Elbow Method2](https://medium.com/@mudgalvivek2911/machine-learning-clustering-elbow-method-4e8c2b404a5d)
#
#     [KMeans](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1)
#
# Let's find out the groups of employees who left. You can observe that the most important factor for any employee to stay or leave is satisfaction and performance in the company. So let's bunch them in the group of people using cluster analysis.

# %%
df_sc_minmax_left = df_sc_minmax[df_sc_minmax['left']==1]

# %%
df_sc_std_left = df_sc_std[df_sc_std['left']==1]

# %% [markdown]
# **K-means with Normalized data (df_sc_minmax)**
# * **Hopkin's Score**

# %%
from pyclustertend import hopkins

hopkins(df_sc_minmax_left.drop('left', axis=1), df_sc_minmax_left.shape[0])
# Out:
# 0.023251719534724834

# %% [markdown]
# * **Elbow method**

# %%
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (2,10))
visu.fit(df_sc_minmax_left.drop('left', axis=1))
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# try elbow for 2 features only
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (2,10))
visu.fit(df_sc_minmax_left[['satisfaction_level', 'last_evaluation']])
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# * **Silhouette Score**

# %%
ssd =[]

K = range(2,10)

for k in K:
    model = KMeans(n_clusters=k)
    model.fit(df_sc_minmax_left)
    ssd.append(model.inertia_)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(df_sc_minmax_left, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.49379396658392216
# Silhouette Score for 3 clusters: 0.5463804752451371
# Silhouette Score for 4 clusters: 0.566445823319715
# Silhouette Score for 5 clusters: 0.5655459737484906
# Silhouette Score for 6 clusters: 0.5513244421814122
# Silhouette Score for 7 clusters: 0.5501456653750347
# Silhouette Score for 8 clusters: 0.564094064626951
# Silhouette Score for 9 clusters: 0.5791781986042857

# %%
# silhauette score for selected features only
ssd =[]

K = range(2,10)

for k in K:
    model = KMeans(n_clusters=k)
    model.fit(df_sc_minmax_left[['satisfaction_level', 'last_evaluation']])
    ssd.append(model.inertia_)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(df_sc_minmax_left, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.3037829541295437
# Silhouette Score for 3 clusters: 0.5329529549878846
# Silhouette Score for 4 clusters: 0.4217343633522516
# Silhouette Score for 5 clusters: 0.3115922284098039
# Silhouette Score for 6 clusters: 0.26553936514914
# Silhouette Score for 7 clusters: 0.06458215801778291
# Silhouette Score for 8 clusters: 0.0666102812354775
# Silhouette Score for 9 clusters: 0.06519765891093186

# %% [markdown]
# **K-means with Standardized data (df_sc_std)**
# * **Hopkin's Score**

# %%
from pyclustertend import hopkins

hopkins(df_sc_std_left, df_sc_std_left.shape[0])
# Out:
# 0.020867270334959758

# %%
# Hopkin's score for selected features

hopkins(df_sc_std_left[['satisfaction_level', 'last_evaluation']], df_sc_std_left[['satisfaction_level', 'last_evaluation']].shape[0])
# Out:
# 0.03734824582095565

# %% [markdown]
# * **Elbow method**

# %%
kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (2,10))
visu.fit(df_sc_std_left)
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Elbow for selected features

kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k = (2,10))
visu.fit(df_sc_std_left[['satisfaction_level', 'last_evaluation']])
visu.poof()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# * **Silhouette Score**

# %%
ssd =[]

K = range(2,10)

for k in K:
    model = KMeans(n_clusters=k)
    model.fit(df_sc_std_left)
    ssd.append(model.inertia_)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(df_sc_std_left, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.53439723798261
# Silhouette Score for 3 clusters: 0.5736480613569883
# Silhouette Score for 4 clusters: 0.5191752809489837
# Silhouette Score for 5 clusters: 0.5318933636222851
# Silhouette Score for 6 clusters: 0.49220278953086344
# Silhouette Score for 7 clusters: 0.46255505471491
# Silhouette Score for 8 clusters: 0.4818704488763577
# Silhouette Score for 9 clusters: 0.5100498068622473

# %%
# silhouette score for selected features

ssd =[]

K = range(2,10)

for k in K:
    model = KMeans(n_clusters=k)
    model.fit(df_sc_std_left[['satisfaction_level', 'last_evaluation']])
    ssd.append(model.inertia_)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(df_sc_std_left, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.30942611743949755
# Silhouette Score for 3 clusters: 0.5557443205279041
# Silhouette Score for 4 clusters: 0.44566078869999043
# Silhouette Score for 5 clusters: 0.3301837979442287
# Silhouette Score for 6 clusters: 0.2906069953115327
# Silhouette Score for 7 clusters: 0.06443030181144214
# Silhouette Score for 8 clusters: 0.06652672182162818
# Silhouette Score for 9 clusters: 0.056357150116861085

# %% [markdown]
# ### K-means clustering of left employees

# %%
df_kmeans = df_sc_std_left[['satisfaction_level', 'last_evaluation']]

kmeans = KMeans(n_clusters=3).fit(df_kmeans)

# %%
clusters = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
plt.figure(figsize=(15, 9))
plt.scatter(df_kmeans.iloc[:, 0], df_kmeans.iloc[:, 1], c=clusters, cmap='viridis')
plt.scatter(centroids[:,0], centroids[:,1], c = "red", s = 200, alpha=0.5)

plt.tight_layout()

# %% [markdown]
# ## 5. Model Building

# %% [markdown]
# <a href="#1.-Exploratory-Data-Analysis">Back to top</a>

# %% [markdown]
# ### Split Data as Train and Test Set

# %% [markdown]
# Here, Dataset is broken into two parts in ratio of 70:30. It means 70% data will used for model training and 30% for model testing.

# %%
df_sc_std.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0           -0.936495        -1.087275       -1.462863             -0.882040
# 1            0.752814         0.840707        0.971113              1.220423
# 2           -2.022479         0.957554        2.593763              1.420657
# 3            0.431041         0.899131        0.971113              0.439508
# 4           -0.976716        -1.145699       -1.462863             -0.841993
#
#    time_spend_company  Work_accident  promotion_last_5years    salary  left
# 0           -0.341235      -0.411165              -0.147412 -0.554955     1
# 1            1.713436      -0.411165              -0.147412  1.043004     1
# 2            0.343655      -0.411165              -0.147412  1.043004     1
# 3            1.028546      -0.411165              -0.147412 -0.554955     1
# 4           -0.341235      -0.411165              -0.147412 -0.554955     1

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

# %%
X = df_sc_std.drop('left', axis=1)
y = df_sc_std['left']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %% [markdown]
# ### #Gradient Boosting Classifier

# %% [markdown]
# #### Model Building

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
model_gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=1).fit(X_train, y_train)

# %%
model_gb.score(X_test, y_test)
# Out:
# 0.9628888888888889

# %% [markdown]
# #### Evaluating Model Performance

# %% [markdown]
# - Confusion Matrix : You can use scikit-learn metrics module for accuracy calculation. A Confusion matrix is an N x N matrix used for evaluating the performance of a classification model, where N is the number of target classes. The matrix compares the actual target values with those predicted by the machine learning model. This gives us a holistic view of how well our classification model is performing and what kinds of errors it is making.
#
#     [Confusion Matrix](https://www.analyticsvidhya.com/blog/2020/04/confusion-matrix-machine-learning/)

# %% [markdown]
# - Yellowbrick: Yellowbrick is a suite of visualization and diagnostic tools that will enable quicker model selection. It’s a Python package that combines scikit-learn and matplotlib. Some of the more popular visualization tools include model selection, feature visualization, classification and regression visualization
#
#     [Yellowbrick](https://www.analyticsvidhya.com/blog/2018/05/yellowbrick-a-set-of-visualization-tools-to-accelerate-your-model-selection-process/)

# %%
y_pred_gb = model_gb.predict(X_test)

# %%
class_rpt = classification_report(y_test, y_pred_gb)
print(class_rpt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3397
#            1       0.93      0.92      0.92      1103
#
#     accuracy                           0.96      4500
#    macro avg       0.95      0.95      0.95      4500
# weighted avg       0.96      0.96      0.96      4500

# %%
conf_mtrx = confusion_matrix(y_test, y_pred_gb)
conf_mtrx
# Out:
# array([[3320,   77],
#        [  90, 1013]], dtype=int64)

# %%
sns.heatmap(conf_mtrx, annot=True, cmap='viridis', fmt='d')
plt.xlabel('Real Values')
plt.ylabel('Predicted Values')
# Out:
# Text(52.0, 0.5, 'Predicted Values')

# %% [markdown]
# ### #KNeighbors Classifier

# %% [markdown]
# #### Model Building

# %%
X = df_sc_std.drop('left', axis=1)
y = df_sc_std['left']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=12)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=1).fit(X_train, y_train)

# %%
model_knn.score(X_test, y_test)
# Out:
# 0.9744444444444444

# %% [markdown]
# #### Evaluating Model Performance

# %%
y_pred_knn = model_knn.predict(X_test)

# %%
# Classification Report

print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      3397
#            1       0.93      0.97      0.95      1103
#
#     accuracy                           0.97      4500
#    macro avg       0.96      0.97      0.97      4500
# weighted avg       0.97      0.97      0.97      4500

# %%
conf_mtrx = confusion_matrix(y_test, y_pred_knn)

# %%
sns.heatmap(conf_mtrx, annot=True, cmap='viridis', fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Choosing K for best model**

# %%
error_rate = []

for i in range(1, 40):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train, y_train)
    y_pred_i = model.predict(X_test)
    error_rate.append(np.mean(y_pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ### #Random Forest Classifier

# %% [markdown]
# #### Model Building

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X = df_sc_std.drop('left', axis=1)
y = df_sc_std['left']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=25)

# %%
model_rf = RandomForestClassifier().fit(X_train, y_train)

# %%
y_pred_rf = model_rf.predict(X_test)

# %% [markdown]
# #### Evaluating Model Performance

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3412
#            1       0.99      0.96      0.97      1088
#
#     accuracy                           0.99      4500
#    macro avg       0.99      0.98      0.98      4500
# weighted avg       0.99      0.99      0.99      4500

# %%
conf_mtrx=confusion_matrix(y_test, y_pred_rf)

# %%
sns.heatmap(conf_mtrx, annot=True, cmap='viridis', fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **RF Tunning**

# %%
rf = RandomForestClassifier()

# %%
rf_params = {"n_estimators" : [50, 100, 300],
             "max_depth" : [3, 5, 7],
             "max_features" : [2, 4, 6, 8],
             "min_samples_split" : [2, 4, 6]}

# %%
rf_cv_model = GridSearchCV(rf, rf_params, cv = 5, n_jobs = -1, verbose = 2).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:  1.9min finished

# %%
rf_cv_model.best_params_
# Out:
# {'max_depth': 7, 'max_features': 8, 'min_samples_split': 4, 'n_estimators': 50}

# %% [markdown]
# **RF Tunned Model**

# %%
model_rf_t = RandomForestClassifier(max_depth= 7, max_features= 8, min_samples_split= 4, n_estimators= 50).fit(X_train, y_train)

# %%
y_pred_rf_t = model_rf_t.predict(X_test)

# %%
print(classification_report(y_test, y_pred_rf_t))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3412
#            1       0.99      0.93      0.96      1088
#
#     accuracy                           0.98      4500
#    macro avg       0.98      0.96      0.97      4500
# weighted avg       0.98      0.98      0.98      4500

# %%
conf_mtrx = confusion_matrix(y_test, y_pred_rf_t)

# %%
sns.heatmap(conf_mtrx, annot=True, cmap='viridis', fmt='d')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a href="#1.-Exploratory-Data-Analysis">Back to top</a>

# %% [markdown]
# ## 6. Model Deployement
#
# You cooked the food in the kitchen and moved on to the serving stage. The question is how do you showcase your work to others? Model Deployement helps you showcase your work to the world and make better decisions with it. But, deploying a model can get a little tricky at times. Before deploying the model, many things such as data storage, preprocessing, model building and monitoring need to be studied. Streamlit is a popular open source framework used by data scientists for model distribution.
#
# Deployment of machine learning models, means making your models available to your other business systems. By deploying models, other systems can send data to them and get their predictions, which are in turn populated back into the company systems. Through machine learning model deployment, can begin to take full advantage of the model you built.
#
# Data science is concerned with how to build machine learning models, which algorithm is more predictive, how to design features, and what variables to use to make the models more accurate. However, how these models are actually used is often neglected. And yet this is the most important step in the machine learning pipline. Only when a model is fully integrated with the business systems, real values ​​can be extract from its predictions.
#
# After doing the following operations in this notebook, jump to new .py file and create your web app with Streamlit.

# %% [markdown]
# ### Save and Export the Model as .pkl

# %% [markdown]
# ### Save and Export Variables as .pkl

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
